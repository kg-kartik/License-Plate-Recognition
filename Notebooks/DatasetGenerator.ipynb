# %%
# %cd ..
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# /
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !pwd
# Out:
# /

# %%
cd content
# Out:
# /content

# %%
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
#  ALPR		    face_emotion	   images   sd
# 'Colab Notebooks'  'Getting started.pdf'   lpr

# %%
# !git clone https://github.com/Francisobiagwu/OIDv4_ToolKit.git
# Out:
# Cloning into 'OIDv4_ToolKit'...
# remote: Enumerating objects: 358, done.
# remote: Total 358 (delta 0), reused 0 (delta 0), pack-reused 358
# Receiving objects: 100% (358/358), 34.03 MiB | 10.16 MiB/s, done.
# Resolving deltas: 100% (107/107), done.

# %%
# %cd OIDv4_ToolKit/
# Out:
# /content/OIDv4_ToolKit

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 3.2MB 2.7MB/s
# ...
#      |████████████████████████████████| 51kB 6.6MB/s
# ...
#      |████████████████████████████████| 6.3MB 21.8MB/s
# ...
#   Found existing installation: rsa 4.6
#     Uninstalling rsa-4.6:
#       Successfully uninstalled rsa-4.6
#   Found existing installation: botocore 1.17.9
#     Uninstalling botocore-1.17.9:
#       Successfully uninstalled botocore-1.17.9
# ...

# %%
# %cd OIDv4_ToolKit
# Out:
# [Errno 2] No such file or directory: 'OIDv4_ToolKit'
# /content/OIDv4_ToolKit

# %%
# !python main.py downloader --classes Vehicle_registration_plate --type_csv train --limit 2000
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
# [INFO] Downloading Vehicle registration plate.
# [ERROR] Missing the train-annotations-bbox.csv file.
# [DOWNLOAD] Do you want to download the missing file? [Y/n] y
# ...100%, 1138 MB, 28567 KB/s, 40 seconds passed
# ...

# %%
# !pwd
# Out:
# /content/OIDv4_ToolKit

# %%
# !python convert_annotations.py
# Out:
# Currently in subdirectory: train
# Converting annotations for class:  Vehicle registration plate
# 100% 2000/2000 [00:42<00:00, 46.79it/s]

# %%
# %cd OID/Dataset/train/Vehicle\ registration\ plate/Label
# Out:
# /content/OIDv4_ToolKit/OID/Dataset/train/Vehicle registration plate/Label

# %%
# %rm *.txt

# %%
# %cd ..
# Out:
# /content/OIDv4_ToolKit/OID/Dataset/train/Vehicle registration plate

# %%
# %cd content/OIDv4_ToolKit/OID/Dataset/train
# Out:
# /content/OIDv4_ToolKit/OID/Dataset/train

# %%
# !zip obj.zip *
# Out:
#   adding: 00009e5b390986a0.jpg (deflated 0%)
#   adding: 00009e5b390986a0.txt (deflated 49%)
#   adding: 000228608388803f.jpg (deflated 0%)
#   adding: 000228608388803f.txt (deflated 35%)
#   adding: 0002a5b67e5f0909.jpg (deflated 0%)
#   adding: 0002a5b67e5f0909.txt (deflated 47%)
#   adding: 00072b81abc72d21.jpg (deflated 0%)
#   adding: 00072b81abc72d21.txt (deflated 32%)
#   adding: 000f52302c1341eb.jpg (deflated 0%)
#   adding: 000f52302c1341eb.txt (deflated 23%)
#   adding: 00103aa8df33633a.jpg (deflated 0%)
#   adding: 00103aa8df33633a.txt (deflated 8%)
#   adding: 0010f4c10f7ab07e.jpg (deflated 0%)
#   adding: 0010f4c10f7ab07e.txt (deflated 37%)
#   adding: 0015ed86d644a332.jpg (deflated 0%)
#   adding: 0015ed86d644a332.txt (deflated 45%)
#   adding: 001bebecea382500.jpg (deflated 0%)
#   adding: 001bebecea382500.txt (deflated 27%)
#   adding: 001ca84e28488f7a.jpg (deflated 0%)
#   adding: 001ca84e28488f7a.txt (deflated 48%)
#   adding: 001cdd25e148cd36.jpg (deflated 0%)
# ...

# %%
# !pwd
# Out:
# /content/OIDv4_ToolKit/OID/Dataset/train/Vehicle registration plate

# %%
# %cd ..
# Out:
# /content

# %%
# !cp OIDv4_ToolKit/OID/Dataset/train/Vehicle\ registration\ plate/obj.zip gdrive/My\ Drive/ALPR
